# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mlb
# %matplotlib inline

# %%
# checking data
fraud=pd.read_csv('Fraud.csv')

# %%
fraud.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
fraud.tail()
# Out:
#          step      type     amount     nameOrig  oldbalanceOrg  \
# 1048570    95  CASH_OUT  132557.35  C1179511630      479803.00
# 1048571    95   PAYMENT    9917.36  C1956161225       90545.00
# 1048572    95   PAYMENT   14140.05  C2037964975       20545.00
# 1048573    95   PAYMENT   10020.05  C1633237354       90605.00
# 1048574    95   PAYMENT   11450.03  C1264356443       80584.95
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 1048570       347245.65   C435674507       484329.37       616886.72        0
# 1048571        80627.64   M668364942            0.00            0.00        0
# 1048572         6404.95  M1355182933            0.00            0.00        0
# 1048573        80584.95  M1964992463            0.00            0.00        0
# 1048574        69134.92   M677577406            0.00            0.00        0
#
#          isFlaggedFraud
# 1048570               0
# 1048571               0
# 1048572               0
# ...

# %%
#checking null values
fraud.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
# using visualization techniques like matplotlib and seaborn to gain more insights
sns.boxplot(x='type',y='amount', data=fraud)
plt.show()

# %%
sns.scatterplot(x='type',y='amount', data=fraud)
plt.show()

# %%
sns.countplot(x='type',data=fraud)
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
sns.scatterplot(x='type',y='isFraud', data=fraud)
plt.show()

# %%
a='isFraud'
num_values = len(set(a))
print(num_values)
# Out:
# 7

# %%
b='type'
num_values = len(set(b))
print(num_values)
# Out:
# 4

# %%
fraud = pd.DataFrame(fraud)

uniqueValues = fraud['isFraud'].nunique()
print(uniqueValues)
# Out:
# 2

# %%
fraud.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
# splitting nameOrig and nameDest into 2 columns for better understanding of data

fraud['nameOrig_1']=fraud['nameOrig'].str.split('').str[1]
fraud['nameOrig_2']=fraud['nameOrig'].str.split('').str[2:]

# %%
fraud.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#   nameOrig_1                        nameOrig_2
# 0          C  [1, 2, 3, 1, 0, 0, 6, 8, 1, 5, ]
# ...

# %%
fraud['nameOrig_3']=fraud['nameOrig_2'].str.join('').str[0:]
fraud.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#   nameOrig_1                        nameOrig_2  nameOrig_3
# ...

# %%
fraud['nameDest_1']=fraud['nameDest'].str.split('').str[1]
fraud['nameDest_2']=fraud['nameDest'].str.split('').str[2:]
fraud.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#   nameOrig_1                        nameOrig_2  nameOrig_3 nameDest_1  \
# ...

# %%
fraud['nameDest_3']=fraud['nameDest_2'].str.join('').str[0:]
fraud.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#   nameOrig_1                        nameOrig_2  nameOrig_3 nameDest_1  \
# ...

# %%
# dropping unwanted columns

fraud=fraud.drop(['nameOrig','nameDest','nameOrig_2','nameDest_2'],axis='columns')
fraud.head()
# Out:
#    step      type    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0     1   PAYMENT   9839.64       170136.0       160296.36             0.0
# 1     1   PAYMENT   1864.28        21249.0        19384.72             0.0
# 2     1  TRANSFER    181.00          181.0            0.00             0.0
# 3     1  CASH_OUT    181.00          181.0            0.00         21182.0
# 4     1   PAYMENT  11668.14        41554.0        29885.86             0.0
#
#    newbalanceDest  isFraud  isFlaggedFraud nameOrig_1  nameOrig_3 nameDest_1  \
# 0             0.0        0               0          C  1231006815          M
# 1             0.0        0               0          C  1666544295          M
# 2             0.0        1               0          C  1305486145          C
# 3             0.0        1               0          C   840083671          C
# 4             0.0        0               0          C  2048537720          M
#
#    nameDest_3
# 0  1979787155
# 1  2044282225
# ...

# %%
# checking datatypes of the columns

fraud.dtypes
# Out:
# step                int64
# type               object
# amount            float64
# oldbalanceOrg     float64
# newbalanceOrig    float64
# oldbalanceDest    float64
# newbalanceDest    float64
# isFraud             int64
# isFlaggedFraud      int64
# nameOrig_1         object
# nameOrig_3         object
# nameDest_1         object
# nameDest_3         object
# dtype: object

# %%
# Using LableEncoder to convert categorical features to numerical one
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
fraud['type'] = encoder.fit_transform(fraud['type'])
fraud['nameOrig_1'] = encoder.fit_transform(fraud['nameOrig_1'])
fraud['nameDest_1'] = encoder.fit_transform(fraud['nameDest_1'])

# %%
fraud.head()
# Out:
#    step  type    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0     1     3   9839.64       170136.0       160296.36             0.0
# 1     1     3   1864.28        21249.0        19384.72             0.0
# 2     1     4    181.00          181.0            0.00             0.0
# 3     1     1    181.00          181.0            0.00         21182.0
# 4     1     3  11668.14        41554.0        29885.86             0.0
#
#    newbalanceDest  isFraud  isFlaggedFraud  nameOrig_1  nameOrig_3  \
# 0             0.0        0               0           0  1231006815
# 1             0.0        0               0           0  1666544295
# 2             0.0        1               0           0  1305486145
# 3             0.0        1               0           0   840083671
# 4             0.0        0               0           0  2048537720
#
#    nameDest_1  nameDest_3
# 0           1  1979787155
# 1           1  2044282225
# 2           0   553264065
# ...

# %%
fraud.dtypes
# Out:
# step                int64
# type                int32
# amount            float64
# oldbalanceOrg     float64
# newbalanceOrig    float64
# oldbalanceDest    float64
# newbalanceDest    float64
# isFraud             int64
# isFlaggedFraud      int64
# nameOrig_1          int32
# nameOrig_3         object
# nameDest_1          int32
# nameDest_3         object
# dtype: object

# %%
# converting float, object datatypes to interger

fraud['type'] =fraud['type'].astype(str).astype(int)

# %%
fraud['amount'] =fraud['amount'].astype(int)

# %%
fraud['oldbalanceOrg'] =fraud['oldbalanceOrg'].astype(int)

# %%
fraud['newbalanceOrig'] =fraud['newbalanceOrig'].astype(int)

# %%
fraud['oldbalanceDest'] =fraud['oldbalanceDest'].astype(int)

# %%
fraud['newbalanceDest'] =fraud['newbalanceDest'].astype(int)

# %%
fraud['nameOrig_1'] =fraud['nameOrig_1'].astype(str).astype(int)

# %%
fraud['nameOrig_3'] =fraud['nameOrig_3'].astype(str).astype(int)

# %%
fraud['nameDest_1'] =fraud['nameDest_1'].astype(str).astype(int)

# %%
fraud['nameDest_3'] =fraud['nameDest_3'].astype(str).astype(int)

# %%
fraud.dtypes
fraud.head()
# Out:
#    step  type  amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0     1     3    9839         170136          160296               0
# 1     1     3    1864          21249           19384               0
# 2     1     4     181            181               0               0
# 3     1     1     181            181               0           21182
# 4     1     3   11668          41554           29885               0
#
#    newbalanceDest  isFraud  isFlaggedFraud  nameOrig_1  nameOrig_3  \
# 0               0        0               0           0  1231006815
# 1               0        0               0           0  1666544295
# 2               0        1               0           0  1305486145
# 3               0        1               0           0   840083671
# 4               0        0               0           0  2048537720
#
#    nameDest_1  nameDest_3
# 0           1  1979787155
# 1           1  2044282225
# 2           0   553264065
# 3           0    38997010
# ...

# %%
# Building a Logistic Regression model

from sklearn.model_selection import train_test_split

# %%
X=fraud.drop('isFraud',axis=1)
y=fraud['isFraud']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
# Training and Predicting

from sklearn.linear_model import LogisticRegression

# %%
logmodel=LogisticRegression()

# %%
logmodel.fit(X_train,y_train)
# Out:
# C:\Users\SAURABH BANNAGARE\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predictions=logmodel.predict(X_test)

# %%
# Evaluation of the model using classification_report and confusion matrix

from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    314239
#            1       0.51      0.35      0.41       334
#
#     accuracy                           1.00    314573
#    macro avg       0.75      0.67      0.71    314573
# weighted avg       1.00      1.00      1.00    314573

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[314125    114]
#  [   217    117]]

# %%
#Prediction

logmodel.score(X_train,y_train)
# Out:
# 0.9989686676603061

# %%
# ANSWERS TO THE QUESTIONS OF ASSIGNMENTS

# Q.1) Describe your fraud detection model in elaboration ? - 
# Ans) The fraud model that is being solved above is used to elaborate fraudulent transactions for a 
#      financial company and use insights from the model to develop an actionable plan. By 
#     using various statistical and visualization methods on the dataset, I came to conclusion 
#    that almost all columns are independent of each other.Though it can be said that most 
#   fraud transaction was done to the customer who is the recipient of the transaction. also for the 
#   type of transcation it seemed that least fraud was attempted when type of transfer was payment.

# Q.2) How did you select variables to be included in the model?
#  Ans) As the problem was a classification related model it, The customer ID and merchent ID 
#      were important in determining the variables for model. 
        
# Q.3) Demonstrate the performance of the model by using best set of tools.
# Ans) I tried to demonstrate the model using evaluation techniques of classification matrix and
#       confusion matrix which helped in getting the accuracy and also F1 score of the model.

# Q.4)What are the key factors that predict fraudulent customer? 
# Ans) According to me, it would be ammount of the transaction and also the type of transcation.

# Q.5) Do these factors make sense? If yes, How? If not, How not?
# Ans) Not much to be honest, we need more details which cause fraudent transcations to be more precise.
  
# Q.6) What kind of prevention should be adopted while company update its infrastructure?
# Ans) We should try to gain more details about customers who are merchants because 
#      there is not information for customers that start with M (Merchants). Also we must come up 
#      steps to control massive transfers from one account to another and flags illegal attempts

# Q.7) Assuming these actions have been implemented, how would you determine if they work?
# Ans) It would be a bit difficult even if we implement the above procedures but keeping a eye on 
#      details of customers (especially the merchants) and also controlling massive transfers would 
#      be a great start.
